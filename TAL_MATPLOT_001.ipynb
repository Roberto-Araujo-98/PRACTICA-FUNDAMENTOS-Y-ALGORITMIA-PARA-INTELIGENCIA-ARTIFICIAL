# %%
import matplotlib.pyplot as plt

# %%
plt.bar(["A","B","C"],[15,20,10], color= ["r","black","yellow"])
plt.title("Gràfico de barras 1")
plt.xlabel("Categorìas")
plt.ylabel("Conteo")
plt.grid(-1)

# %%
plt.scatter([1,2,3],[2,4,6], marker ="")
plt.title("Gràfico de dispersión")
# Out:
# Text(0.5, 1.0, 'Gràfico de dispersión')

# %%
plt.plot([1,2,3],[2,4,6])
plt.title("Gráfico de lìneas")
# Out:
# Text(0.5, 1.0, 'Gráfico de lìneas')

# %%
plt.pie([100,100], labels = ["A","B"], autopct='%1.1f%%' )
# Out:
# ([<matplotlib.patches.Wedge at 0x7c479a07fed0>,
# ...
#  [Text(-4.8082529002048655e-08, 1.099999999999999, 'A'),
#   Text(1.311736850028664e-08, -1.0999999999999999, 'B')],
#  [Text(-2.6226834001117445e-08, 0.5999999999999994, '50.0%'),
#   Text(7.1549282728836204e-09, -0.5999999999999999, '50.0%')])

# %%
plt.hist([20,10,18,10,21,19,20,21,22,23,24,25], bins =2, edgecolor="green")
# Out:
# (array([ 2., 10.]),
#  array([10. , 17.5, 25. ]),
#  <BarContainer object of 2 artists>)

# %%
plt.bar(["a","b","c"], [48,85,60])
plt.title("Votos por serie")
# Out:
# Text(0.5, 1.0, 'Votos por serie')

# %%
plt.scatter([5,7,8,5,6,9], [110,120,130, 105,115,135], marker= "v")

# %%
plt.hist([12,15,14,19,11,15,16,14,15,18,20,11,14,15,16], bins=3)
plt.title("XD")
# Out:
# Text(0.5, 1.0, 'XD')
