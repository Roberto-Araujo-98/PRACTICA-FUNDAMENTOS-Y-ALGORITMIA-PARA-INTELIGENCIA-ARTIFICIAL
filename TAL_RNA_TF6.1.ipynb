# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist #Dígitos manuscritos (70000 muestras)

# %%
(x_train, y_train),(x_test, y_test)= mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print("Forma de la imagen:", x_test[0].shape)
print('Forma de x_train', x_train.shape)
print('Forma de x_train', x_test.shape)
print('Total del muestras', (len(y_train)+len(y_test)))
# Out:
# Forma de la imagen: (28, 28)
# Forma de x_train (60000, 28, 28)
# Forma de x_train (10000, 28, 28)
# Total del muestras 70000

# %%
for s in range(10):
  plt.subplot(2,5, s+1)
  plt.imshow(x_test[s], cmap = "gray")
  plt.title(y_test[s])
plt.tight_layout()

# %%
x_train = x_train/255.0
x_test = x_test/255.0
"print(x_test[0])"
# Out:
# 'print(x_test[0])'

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape = (28,28)), #Convertimos la imagen 2d a un vector plano de numeros(las capas densas solo admiten imagenes planas)
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'softmax')
])
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
a = 28
print( "El numero a elevado al cuadrado es:",a **2)
# Out:
# El numero a elevado al cuadrado es: 784

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9270 - loss: 0.2540
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9671 - loss: 0.1084
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9772 - loss: 0.0760
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9821 - loss: 0.0568
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9861 - loss: 0.0441
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9896 - loss: 0.0335
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9913 - loss: 0.0276
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9928 - loss: 0.0230
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9945 - loss: 0.0187
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9951 - loss: 0.0161
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9955 - loss: 0.0136
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9964 - loss: 0.0110
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9973 - loss: 0.0089
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9971 - loss: 0.0092
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9979 - loss: 0.0069

# %%
muestra= x_test[10].reshape(1,28,28)
predict= model.predict(muestra)
print('Salida de probabilidades de nuestro softmax', predict)
print('Afinando la salida', predict.argmax(1))
print('Etiqueta real', y_test[10])
plt.imshow(muestra.reshape(28,28), cmap = 'gray')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Salida de probabilidades de nuestro softmax [[1.00000000e+00 8.14893672e-18 9.75165851e-11 1.39708747e-13
#   7.87492616e-20 6.38183777e-12 5.94122136e-13 1.38314785e-11
#   1.38498093e-17 1.53053359e-09]]
# Afinando la salida [0]
# Etiqueta real 0
